# %%
# !pip install gql requests
# Out:
# Requirement already satisfied: gql in /usr/local/lib/python3.11/dist-packages (3.5.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: graphql-core<3.2.4,>=3.2 in /usr/local/lib/python3.11/dist-packages (from gql) (3.2.3)
# Requirement already satisfied: yarl<2.0,>=1.6 in /usr/local/lib/python3.11/dist-packages (from gql) (1.18.3)
# Requirement already satisfied: backoff<3.0,>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from gql) (2.2.1)
# Requirement already satisfied: anyio<5,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gql) (3.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.0->gql) (1.3.1)
# Requirement already satisfied: multidict>=4.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.6->gql) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.6->gql) (0.2.1)

# %%
import requests
import json
import pandas as pd
import time

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport

# TODO LEMBRETE - Ao fazer o commit, colocar placeholder em vez do token
GITHUB_TOKEN = "TOKEN_GITHUB"

transport = RequestsHTTPTransport(
    url="https://api.github.com/graphql",
    headers={"Authorization": f"Bearer {GITHUB_TOKEN}"},
    use_json=True,
    timeout=60
)

client = Client(transport=transport, fetch_schema_from_transport=True)

# %%
query_basic_info = """
query ($cursor: String) {
  search(query: "stars:>1", type: REPOSITORY, first: 100, after: $cursor) {
    pageInfo {
      hasNextPage
      endCursor
    }
    nodes {
      ... on Repository {
        name
        owner {
          login
        }
        createdAt
        updatedAt
        primaryLanguage {
          name
        }
        pullRequests(states: MERGED) {
          totalCount
        }
      }
    }
  }
}
"""

# %%
repos = []
cursor = None
total_repos = 0

while total_repos < 1000:
    print(f"🔄 Fetching repositories {total_repos + 1} to {total_repos + 100}...")

    variables = {"cursor": cursor}

    try:
        response = client.execute(gql(query_basic_info), variable_values=variables)
        repos += response["search"]["nodes"]
        total_repos = len(repos)

        page_info = response["search"]["pageInfo"]
        if not page_info["hasNextPage"]:
            break

        cursor = page_info["endCursor"]

    except Exception as e:
        print(f"⚠️ Error fetching repositories: {e}")
        time.sleep(10)
        continue

print(f"✅ Repository collection complete! Total: {total_repos}")
# Out:
# 🔄 Fetching repositories 1 to 100...
# 🔄 Fetching repositories 101 to 200...
# 🔄 Fetching repositories 201 to 300...
# 🔄 Fetching repositories 301 to 400...
# 🔄 Fetching repositories 401 to 500...
# 🔄 Fetching repositories 501 to 600...
# 🔄 Fetching repositories 601 to 700...
# 🔄 Fetching repositories 701 to 800...
# 🔄 Fetching repositories 801 to 900...
# 🔄 Fetching repositories 901 to 1000...
# ✅ Repository collection complete! Total: 1000

# %%
query_extra_info = """
query ($repoOwner: String!, $repoName: String!) {
  repository(owner: $repoOwner, name: $repoName) {
    releases(first: 1) {
      totalCount
    }
    issues(first: 1) {
      totalCount
    }
    closedIssues: issues(states: CLOSED, first: 1) {
      totalCount
    }
    stargazers(first: 1) {
      totalCount
    }
  }
}
"""

# %%
for repo in repos:
    repo_owner = repo["owner"]["login"]
    repo_name = repo["name"]

    print(f"🔄 Fetching extra details for {repo_owner}/{repo_name}...")

    variables = {"repoOwner": repo_owner, "repoName": repo_name}

    try:
        extra_data = client.execute(gql(query_extra_info), variable_values=variables)
        repo.update(extra_data["repository"])

    except Exception as e:
        print(f"⚠️ Error fetching details for {repo_owner}/{repo_name}: {e}")
        time.sleep(10)
        continue

print("✅ Extra data collection complete!")
# Out:
# 🔄 Fetching extra details for freeCodeCamp/freeCodeCamp...
# 🔄 Fetching extra details for EbookFoundation/free-programming-books...
# 🔄 Fetching extra details for sindresorhus/awesome...
# 🔄 Fetching extra details for codecrafters-io/build-your-own-x...
# 🔄 Fetching extra details for public-apis/public-apis...
# 🔄 Fetching extra details for jwasham/coding-interview-university...
# 🔄 Fetching extra details for kamranahmedse/developer-roadmap...
# 🔄 Fetching extra details for donnemartin/system-design-primer...
# 🔄 Fetching extra details for 996icu/996.ICU...
# 🔄 Fetching extra details for vinta/awesome-python...
# 🔄 Fetching extra details for facebook/react...
# 🔄 Fetching extra details for practical-tutorials/project-based-learning...
# 🔄 Fetching extra details for awesome-selfhosted/awesome-selfhosted...
# 🔄 Fetching extra details for vuejs/vue...
# 🔄 Fetching extra details for TheAlgorithms/Python...
# 🔄 Fetching extra details for trekhleb/javascript-algorithms...
# 🔄 Fetching extra details for torvalds/linux...
# 🔄 Fetching extra details for tensorflow/tensorflow...
# 🔄 Fetching extra details for getify/You-Dont-Know-JS...
# 🔄 Fetching extra details for CyC2018/CS-Notes...
# 🔄 Fetching extra details for ohmyzsh/ohmyzsh...
# 🔄 Fetching extra details for ossu/computer-science...
# 🔄 Fetching extra details for Significant-Gravitas/AutoGPT...
# 🔄 Fetching extra details for twbs/bootstrap...
# 🔄 Fetching extra details for flutter/flutter...
# 🔄 Fetching extra details for microsoft/vscode...
# 🔄 Fetching extra details for github/gitignore...
# 🔄 Fetching extra details for jackfrued/Python-100-Days...
# 🔄 Fetching extra details for trimstray/the-book-of-secret-knowledge...
# 🔄 Fetching extra details for jlevy/the-art-of-command-line...
# 🔄 Fetching extra details for AUTOMATIC1111/stable-diffusion-webui...
# 🔄 Fetching extra details for Snailclimb/JavaGuide...
# 🔄 Fetching extra details for airbnb/javascript...
# 🔄 Fetching extra details for huggingface/transformers...
# 🔄 Fetching extra details for avelino/awesome-go...
# 🔄 Fetching extra details for ytdl-org/youtube-dl...
# 🔄 Fetching extra details for vercel/next.js...
# 🔄 Fetching extra details for ollama/ollama...
# 🔄 Fetching extra details for labuladong/fucking-algorithm...
# 🔄 Fetching extra details for golang/go...
# 🔄 Fetching extra details for Chalarangelo/30-seconds-of-code...
# 🔄 Fetching extra details for yangshun/tech-interview-handbook...
# 🔄 Fetching extra details for massgravel/Microsoft-Activation-Scripts...
# 🔄 Fetching extra details for f/awesome-chatgpt-prompts...
# 🔄 Fetching extra details for facebook/react-native...
# 🔄 Fetching extra details for Genymobile/scrcpy...
# 🔄 Fetching extra details for electron/electron...
# 🔄 Fetching extra details for microsoft/PowerToys...
# 🔄 Fetching extra details for kubernetes/kubernetes...
# 🔄 Fetching extra details for justjavac/free-programming-books-zh_CN...
# 🔄 Fetching extra details for d3/d3...
# 🔄 Fetching extra details for nodejs/node...
# 🔄 Fetching extra details for krahets/hello-algo...
# 🔄 Fetching extra details for axios/axios...
# 🔄 Fetching extra details for mrdoob/three.js...
# 🔄 Fetching extra details for facebook/create-react-app...
# 🔄 Fetching extra details for microsoft/TypeScript...
# 🔄 Fetching extra details for denoland/deno...
# 🔄 Fetching extra details for goldbergyoni/nodebestpractices...
# 🔄 Fetching extra details for rust-lang/rust...
# 🔄 Fetching extra details for yt-dlp/yt-dlp...
# 🔄 Fetching extra details for langchain-ai/langchain...
# 🔄 Fetching extra details for 521xueweihan/HelloGitHub...
# 🔄 Fetching extra details for microsoft/terminal...
# 🔄 Fetching extra details for angular/angular...
# 🔄 Fetching extra details for mui/material-ui...
# 🔄 Fetching extra details for godotengine/godot...
# 🔄 Fetching extra details for ant-design/ant-design...
# 🔄 Fetching extra details for excalidraw/excalidraw...
# 🔄 Fetching extra details for ryanmcdermott/clean-code-javascript...
# 🔄 Fetching extra details for ripienaar/free-for-dev...
# 🔄 Fetching extra details for papers-we-love/papers-we-love...
# 🔄 Fetching extra details for iluwatar/java-design-patterns...
# 🔄 Fetching extra details for fatedier/frp...
# 🔄 Fetching extra details for iptv-org/iptv...
# 🔄 Fetching extra details for nvbn/thefuck...
# 🔄 Fetching extra details for puppeteer/puppeteer...
# 🔄 Fetching extra details for tauri-apps/tauri...
# 🔄 Fetching extra details for Hack-with-Github/Awesome-Hacking...
# 🔄 Fetching extra details for PanJiaChen/vue-element-admin...
# 🔄 Fetching extra details for deepseek-ai/DeepSeek-V3...
# 🔄 Fetching extra details for pytorch/pytorch...
# 🔄 Fetching extra details for neovim/neovim...
# 🔄 Fetching extra details for mtdvio/every-programmer-should-know...
# 🔄 Fetching extra details for storybookjs/storybook...
# 🔄 Fetching extra details for tailwindlabs/tailwindcss...
# 🔄 Fetching extra details for microsoft/Web-Dev-For-Beginners...
# 🔄 Fetching extra details for rustdesk/rustdesk...
# 🔄 Fetching extra details for django/django...
# 🔄 Fetching extra details for nvm-sh/nvm...
# 🔄 Fetching extra details for florinpop17/app-ideas...
# 🔄 Fetching extra details for bitcoin/bitcoin...
# 🔄 Fetching extra details for sveltejs/svelte...
# 🔄 Fetching extra details for shadcn-ui/ui...
# 🔄 Fetching extra details for animate-css/animate.css...
# 🔄 Fetching extra details for fastapi/fastapi...
# 🔄 Fetching extra details for gothinkster/realworld...
# 🔄 Fetching extra details for ChatGPTNextWeb/NextChat...
# 🔄 Fetching extra details for opencv/opencv...
# 🔄 Fetching extra details for gin-gonic/gin...
# 🔄 Fetching extra details for deepseek-ai/DeepSeek-R1...
# 🔄 Fetching extra details for jaywcjlove/awesome-mac...
# 🔄 Fetching extra details for laravel/laravel...
# 🔄 Fetching extra details for macrozheng/mall...
# 🔄 Fetching extra details for gohugoio/hugo...
# 🔄 Fetching extra details for tonsky/FiraCode...
# 🔄 Fetching extra details for open-webui/open-webui...
# 🔄 Fetching extra details for supabase/supabase...
# 🔄 Fetching extra details for tensorflow/models...
# 🔄 Fetching extra details for doocs/advanced-java...
# 🔄 Fetching extra details for openai/whisper...
# 🔄 Fetching extra details for home-assistant/core...
# 🔄 Fetching extra details for oven-sh/bun...
# 🔄 Fetching extra details for spring-projects/spring-boot...
# 🔄 Fetching extra details for mermaid-js/mermaid...
# 🔄 Fetching extra details for MisterBooo/LeetCodeAnimation...
# 🔄 Fetching extra details for 2dust/v2rayN...
# 🔄 Fetching extra details for 3b1b/manim...
# 🔄 Fetching extra details for ggml-org/llama.cpp...
# 🔄 Fetching extra details for FortAwesome/Font-Awesome...
# 🔄 Fetching extra details for typicode/json-server...
# 🔄 Fetching extra details for netdata/netdata...
# 🔄 Fetching extra details for DopplerHQ/awesome-interview-questions...
# 🔄 Fetching extra details for vuejs/awesome-vue...
# 🔄 Fetching extra details for nomic-ai/gpt4all...
# 🔄 Fetching extra details for MunGell/awesome-for-beginners...
# 🔄 Fetching extra details for elastic/elasticsearch...
# 🔄 Fetching extra details for anuraghazra/github-readme-stats...
# 🔄 Fetching extra details for microsoft/generative-ai-for-beginners...
# 🔄 Fetching extra details for langgenius/dify...
# 🔄 Fetching extra details for microsoft/ML-For-Beginners...
# 🔄 Fetching extra details for fighting41love/funNLP...
# 🔄 Fetching extra details for vitejs/vite...
# 🔄 Fetching extra details for coder/code-server...
# 🔄 Fetching extra details for CompVis/stable-diffusion...
# 🔄 Fetching extra details for thedaviddias/Front-End-Checklist...
# 🔄 Fetching extra details for microsoft/playwright...
# 🔄 Fetching extra details for nestjs/nest...
# 🔄 Fetching extra details for moby/moby...
# 🔄 Fetching extra details for Anduin2017/HowToCook...
# 🔄 Fetching extra details for pallets/flask...
# 🔄 Fetching extra details for ByteByteGoHq/system-design-101...
# 🔄 Fetching extra details for base/node...
# 🔄 Fetching extra details for abi/screenshot-to-code...
# 🔄 Fetching extra details for hoppscotch/hoppscotch...
# 🔄 Fetching extra details for hakimel/reveal.js...
# 🔄 Fetching extra details for comfyanonymous/ComfyUI...
# 🔄 Fetching extra details for bregman-arie/devops-exercises...
# 🔄 Fetching extra details for junegunn/fzf...
# 🔄 Fetching extra details for Developer-Y/cs-video-courses...
# 🔄 Fetching extra details for swiftlang/swift...
# 🔄 Fetching extra details for redis/redis...
# 🔄 Fetching extra details for syncthing/syncthing...
# 🔄 Fetching extra details for binary-husky/gpt_academic...
# 🔄 Fetching extra details for josephmisiti/awesome-machine-learning...
# 🔄 Fetching extra details for enaqx/awesome-react...
# 🔄 Fetching extra details for protocolbuffers/protobuf...
# 🔄 Fetching extra details for grafana/grafana...
# 🔄 Fetching extra details for expressjs/express...
# 🔄 Fetching extra details for sdmg15/Best-websites-a-programmer-should-visit...
# 🔄 Fetching extra details for d2l-ai/d2l-zh...
# 🔄 Fetching extra details for python/cpython...
# 🔄 Fetching extra details for chartjs/Chart.js...
# 🔄 Fetching extra details for strapi/strapi...
# 🔄 Fetching extra details for ventoy/Ventoy...
# 🔄 Fetching extra details for webpack/webpack...
# 🔄 Fetching extra details for louislam/uptime-kuma...
# 🔄 Fetching extra details for tesseract-ocr/tesseract...
# 🔄 Fetching extra details for leonardomso/33-js-concepts...
# 🔄 Fetching extra details for apache/superset...
# 🔄 Fetching extra details for ansible/ansible...
# 🔄 Fetching extra details for kdn251/interviews...
# 🔄 Fetching extra details for xtekky/gpt4free...
# 🔄 Fetching extra details for lydiahallie/javascript-questions...
# 🔄 Fetching extra details for swisskyrepo/PayloadsAllTheThings...
# 🔄 Fetching extra details for ocornut/imgui...
# 🔄 Fetching extra details for twitter/the-algorithm...
# 🔄 Fetching extra details for sherlock-project/sherlock...
# 🔄 Fetching extra details for keras-team/keras...
# 🔄 Fetching extra details for n8n-io/n8n...
# 🔄 Fetching extra details for FuelLabs/sway...
# 🔄 Fetching extra details for obsproject/obs-studio...
# 🔄 Fetching extra details for resume/resume.github.com...
# 🔄 Fetching extra details for awesomedata/awesome-public-datasets...
# 🔄 Fetching extra details for Eugeny/tabby...
# 🔄 Fetching extra details for fffaraz/awesome-cpp...
# 🔄 Fetching extra details for openai/openai-cookbook...
# 🔄 Fetching extra details for apache/echarts...
# 🔄 Fetching extra details for caddyserver/caddy...
# 🔄 Fetching extra details for socketio/socket.io...
# 🔄 Fetching extra details for kelseyhightower/nocode...
# 🔄 Fetching extra details for scikit-learn/scikit-learn...
# 🔄 Fetching extra details for reduxjs/redux...
# 🔄 Fetching extra details for danielmiessler/SecLists...
# 🔄 Fetching extra details for TheAlgorithms/Java...
# 🔄 Fetching extra details for AppFlowy-IO/AppFlowy...
# 🔄 Fetching extra details for chrislgarry/Apollo-11...
# 🔄 Fetching extra details for binhnguyennus/awesome-scalability...
# 🔄 Fetching extra details for PKUFlyingPig/cs-self-learning...
# 🔄 Fetching extra details for atom/atom...
# 🔄 Fetching extra details for lodash/lodash...
# 🔄 Fetching extra details for xingshaocheng/architect-awesome...
# 🔄 Fetching extra details for h5bp/Front-end-Developer-Interview-Questions...
# 🔄 Fetching extra details for bradtraversy/design-resources-for-developers...
# 🔄 Fetching extra details for adam-p/markdown-here...
# 🔄 Fetching extra details for sindresorhus/awesome-nodejs...
# 🔄 Fetching extra details for jquery/jquery...
# 🔄 Fetching extra details for prakhar1989/awesome-courses...
# 🔄 Fetching extra details for Alvin9999/new-pac...
# 🔄 Fetching extra details for immich-app/immich...
# 🔄 Fetching extra details for angular/angular.js...
# 🔄 Fetching extra details for labmlai/annotated_deep_learning_paper_implementations...
# 🔄 Fetching extra details for shadowsocks/shadowsocks-windows...
# 🔄 Fetching extra details for facebook/docusaurus...
# 🔄 Fetching extra details for OpenInterpreter/open-interpreter...
# 🔄 Fetching extra details for nektos/act...
# 🔄 Fetching extra details for localsend/localsend...
# 🔄 Fetching extra details for localstack/localstack...
# 🔄 Fetching extra details for FuelLabs/fuel-core...
# 🔄 Fetching extra details for alacritty/alacritty...
# 🔄 Fetching extra details for meta-llama/llama...
# 🔄 Fetching extra details for spring-projects/spring-framework...
# 🔄 Fetching extra details for prometheus/prometheus...
# 🔄 Fetching extra details for jesseduffield/lazygit...
# 🔄 Fetching extra details for h5bp/html5-boilerplate...
# 🔄 Fetching extra details for rust-lang/rustlings...
# 🔄 Fetching extra details for rails/rails...
# 🔄 Fetching extra details for ryanoasis/nerd-fonts...
# 🔄 Fetching extra details for nuxt/nuxt...
# 🔄 Fetching extra details for lobehub/lobe-chat...
# 🔄 Fetching extra details for gatsbyjs/gatsby...
# 🔄 Fetching extra details for scutan90/DeepLearning-500-questions...
# 🔄 Fetching extra details for zylon-ai/private-gpt...
# 🔄 Fetching extra details for soimort/you-get...
# 🔄 Fetching extra details for azl397985856/leetcode...
# 🔄 Fetching extra details for Solido/awesome-flutter...
# 🔄 Fetching extra details for zed-industries/zed...
# 🔄 Fetching extra details for NationalSecurityAgency/ghidra...
# 🔄 Fetching extra details for PlexPt/awesome-chatgpt-prompts-zh...
# 🔄 Fetching extra details for scrapy/scrapy...
# 🔄 Fetching extra details for ageitgey/face_recognition...
# 🔄 Fetching extra details for ElemeFE/element...
# 🔄 Fetching extra details for remix-run/react-router...
# 🔄 Fetching extra details for youngyangyang04/leetcode-master...
# 🔄 Fetching extra details for tldr-pages/tldr...
# 🔄 Fetching extra details for lencx/ChatGPT...
# 🔄 Fetching extra details for git/git...
# 🔄 Fetching extra details for CorentinJ/Real-Time-Voice-Cloning...
# 🔄 Fetching extra details for dair-ai/Prompt-Engineering-Guide...
# 🔄 Fetching extra details for traefik/traefik...
# 🔄 Fetching extra details for deepfakes/faceswap...
# 🔄 Fetching extra details for AntonOsika/gpt-engineer...
# 🔄 Fetching extra details for necolas/normalize.css...
# 🔄 Fetching extra details for ruanyf/weekly...
# 🔄 Fetching extra details for jgraph/drawio-desktop...
# 🔄 Fetching extra details for commaai/openpilot...
# 🔄 Fetching extra details for psf/requests...
# 🔄 Fetching extra details for ultralytics/yolov5...
# 🔄 Fetching extra details for FiloSottile/mkcert...
# 🔄 Fetching extra details for nocodb/nocodb...
# 🔄 Fetching extra details for Stirling-Tools/Stirling-PDF...
# 🔄 Fetching extra details for Z4nzu/hackingtool...
# 🔄 Fetching extra details for wasabeef/awesome-android-ui...
# 🔄 Fetching extra details for ionic-team/ionic-framework...
# 🔄 Fetching extra details for sharkdp/bat...
# 🔄 Fetching extra details for Semantic-Org/Semantic-UI...
# 🔄 Fetching extra details for google/material-design-icons...
# 🔄 Fetching extra details for golang-standards/project-layout...
# 🔄 Fetching extra details for topjohnwu/Magisk...
# 🔄 Fetching extra details for juliangarnier/anime...
# 🔄 Fetching extra details for Textualize/rich...
# 🔄 Fetching extra details for google/guava...
# 🔄 Fetching extra details for pi-hole/pi-hole...
# 🔄 Fetching extra details for BurntSushi/ripgrep...
# 🔄 Fetching extra details for pmndrs/zustand...
# 🔄 Fetching extra details for minio/minio...
# 🔄 Fetching extra details for xai-org/grok-1...
# 🔄 Fetching extra details for JetBrains/kotlin...
# 🔄 Fetching extra details for prettier/prettier...
# 🔄 Fetching extra details for gorhill/uBlock...
# 🔄 Fetching extra details for mozilla/pdf.js...
# 🔄 Fetching extra details for sickcodes/Docker-OSX...
# 🔄 Fetching extra details for tiimgreen/github-cheat-sheet...
# 🔄 Fetching extra details for jekyll/jekyll...
# 🔄 Fetching extra details for wagoodman/dive...
# 🔄 Fetching extra details for jgthms/bulma...
# 🔄 Fetching extra details for meilisearch/meilisearch...
# 🔄 Fetching extra details for withastro/astro...
# 🔄 Fetching extra details for DefinitelyTyped/DefinitelyTyped...
# 🔄 Fetching extra details for langflow-ai/langflow...
# 🔄 Fetching extra details for rclone/rclone...
# 🔄 Fetching extra details for facebookresearch/segment-anything...
# 🔄 Fetching extra details for vuejs/core...
# 🔄 Fetching extra details for rust-unofficial/awesome-rust...
# 🔄 Fetching extra details for ngosang/trackerslist...
# 🔄 Fetching extra details for chinese-poetry/chinese-poetry...
# 🔄 Fetching extra details for marktext/marktext...
# 🔄 Fetching extra details for TryGhost/Ghost...
# 🔄 Fetching extra details for etcd-io/etcd...
# 🔄 Fetching extra details for ethereum/go-ethereum...
# 🔄 Fetching extra details for vsouza/awesome-ios...
# 🔄 Fetching extra details for cypress-io/cypress...
# 🔄 Fetching extra details for clash-verge-rev/clash-verge-rev...
# 🔄 Fetching extra details for moment/moment...
# 🔄 Fetching extra details for ReactiveX/RxJava...
# 🔄 Fetching extra details for romkatv/powerlevel10k...
# 🔄 Fetching extra details for NARKOZ/hacker-scripts...
# 🔄 Fetching extra details for FFmpeg/FFmpeg...
# 🔄 Fetching extra details for laurent22/joplin...
# 🔄 Fetching extra details for mastodon/mastodon...
# 🔄 Fetching extra details for All-Hands-AI/OpenHands...
# 🔄 Fetching extra details for poteto/hiring-without-whiteboards...
# 🔄 Fetching extra details for iamkun/dayjs...
# 🔄 Fetching extra details for geekan/MetaGPT...
# 🔄 Fetching extra details for appwrite/appwrite...
# 🔄 Fetching extra details for charlax/professional-programming...
# 🔄 Fetching extra details for go-gitea/gitea...
# 🔄 Fetching extra details for starship/starship...
# 🔄 Fetching extra details for WerWolv/ImHex...
# 🔄 Fetching extra details for algorithm-visualizer/algorithm-visualizer...
# 🔄 Fetching extra details for firstcontributions/first-contributions...
# 🔄 Fetching extra details for minimaxir/big-list-of-naughty-strings...
# 🔄 Fetching extra details for mlabonne/llm-course...
# 🔄 Fetching extra details for justjavac/awesome-wechat-weapp...
# 🔄 Fetching extra details for agalwood/Motrix...
# 🔄 Fetching extra details for PaddlePaddle/PaddleOCR...
# 🔄 Fetching extra details for serverless/serverless...
# 🔄 Fetching extra details for PowerShell/PowerShell...
# 🔄 Fetching extra details for AlistGo/alist...
# 🔄 Fetching extra details for Avik-Jain/100-Days-Of-ML-Code...
# 🔄 Fetching extra details for JuliaLang/julia...
# 🔄 Fetching extra details for square/okhttp...
# 🔄 Fetching extra details for kamranahmedse/design-patterns-for-humans...
# 🔄 Fetching extra details for typescript-cheatsheets/react...
# 🔄 Fetching extra details for toeverything/AFFiNE...
# 🔄 Fetching extra details for ziishaned/learn-regex...
# 🔄 Fetching extra details for karan/Projects...
# 🔄 Fetching extra details for v2ray/v2ray-core...
# 🔄 Fetching extra details for gogs/gogs...
# 🔄 Fetching extra details for x64dbg/x64dbg...
# 🔄 Fetching extra details for huginn/huginn...
# 🔄 Fetching extra details for android/architecture-samples...
# 🔄 Fetching extra details for Asabeneh/30-Days-Of-Python...
# 🔄 Fetching extra details for slab/quill...
# 🔄 Fetching extra details for pandas-dev/pandas...
# 🔄 Fetching extra details for pixijs/pixijs...
# 🔄 Fetching extra details for meteor/meteor...
# 🔄 Fetching extra details for jestjs/jest...
# 🔄 Fetching extra details for nlohmann/json...
# 🔄 Fetching extra details for type-challenges/type-challenges...
# 🔄 Fetching extra details for ColorlibHQ/AdminLTE...
# 🔄 Fetching extra details for hashicorp/terraform...
# 🔄 Fetching extra details for hacksider/Deep-Live-Cam...
# 🔄 Fetching extra details for dkhamsing/open-source-ios-apps...
# 🔄 Fetching extra details for Asabeneh/30-Days-Of-JavaScript...
# 🔄 Fetching extra details for jakevdp/PythonDataScienceHandbook...
# 🔄 Fetching extra details for TanStack/query...
# 🔄 Fetching extra details for FuelLabs/fuels-ts...
# 🔄 Fetching extra details for pocketbase/pocketbase...
# 🔄 Fetching extra details for FuelLabs/fuels-rs...
# 🔄 Fetching extra details for vercel/hyper...
# 🔄 Fetching extra details for parcel-bundler/parcel...
# 🔄 Fetching extra details for bigskysoftware/htmx...
# 🔄 Fetching extra details for brillout/awesome-react-components...
# 🔄 Fetching extra details for google/zx...
# 🔄 Fetching extra details for aymericdamien/TensorFlow-Examples...
# 🔄 Fetching extra details for astaxie/build-web-application-with-golang...
# 🔄 Fetching extra details for babel/babel...
# 🔄 Fetching extra details for lllyasviel/Fooocus...
# 🔄 Fetching extra details for square/retrofit...
# 🔄 Fetching extra details for isocpp/CppCoreGuidelines...
# 🔄 Fetching extra details for discourse/discourse...

# %%
df = pd.DataFrame(repos)
df.head()

# %%
# Corrigir a coluna 'owner' para mostrar apenas o login
df["owner"] = df['owner'].apply(lambda x: x['login'] if isinstance(x, dict) else x)

# Corrigir a coluna 'primaryLanguage' para mostrar apenas o nome da linguagem
df["primaryLanguage"] = df["primaryLanguage"].apply(lambda x: x["name"] if isinstance(x, dict) else None)

# Corrigir as colunas que contêm dicionários com 'totalCount'
columns_to_fix = ["pullRequests", "releases", "issues", "closedIssues", "stargazers"]
for col in columns_to_fix:
    df[col] = df[col].apply(lambda x: x["totalCount"] if isinstance(x, dict) else 0)

df

# %%
df.to_csv("formatted_github_data.csv", index=False)
